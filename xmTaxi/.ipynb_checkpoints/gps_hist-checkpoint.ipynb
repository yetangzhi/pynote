# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pyproj as proj
g = proj.Geod(ellps='WGS84')

# %%
gps = pd.read_csv('20141001_gps.csv',parse_dates=[2])

# %%
tdif = np.diff(gps['TIME'])[np.diff(gps['MOVER_ID'])==0]
fig,ax = plt.subplots()
ax.hist(tdif.astype(int)/10**9,bins=250,range=(0,250))
fig.show()
# Out:
# /System/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:387: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
cleanIdx1 = np.logical_and(gps.X >  115.753656,gps.X < 119.664789)
cleanIdx2 = np.logical_and(gps.Y > 23.234255,gps.Y <26.153442)
cIdx = np.logical_and(cleanIdx1,cleanIdx2)
cIdx.value_counts()
# Out:
# True     6462821
# False       5989
# dtype: int64

# %%
cleanIdx1 = np.logical_and(gps.X >  118.201627,gps.X < 118.804345)
cleanIdx2 = np.logical_and(gps.Y > 24.449411,gps.Y <24.526584)
cIdx2 = np.logical_and(cleanIdx1,cleanIdx2)
cIdx2.value_counts()
# Out:
# False    6468787
# True          23
# dtype: int64

# %%
cIdx = np.logical_and(cIdx,np.logical_not(cIdx2))
cIdx.value_counts()
# Out:
# True     6462798
# False       6012
# dtype: int64

# %%
cleanIdx1 = np.logical_and(gps.X >  118.072538,gps.X < 118.482465)
cleanIdx2 = np.logical_and(gps.Y > 23.889365,gps.Y <24.420655)
cIdx3 = np.logical_and(cleanIdx1,cleanIdx2)
cIdx3.value_counts()
# Out:
# False    6468781
# True          29
# dtype: int64

# %%
cIdx = np.logical_and(cIdx,np.logical_not(cIdx3))
cIdx.value_counts()
# Out:
# True     6462769
# False       6041
# dtype: int64

# %%
cleanIdx1 = np.logical_and(gps.X >  118.050956,gps.X < 118.545341)
cleanIdx2 = np.logical_and(gps.Y > 23.971704,gps.Y <24.293167 )
cIdx4 = np.logical_and(cleanIdx1,cleanIdx2)
cIdx4.value_counts()
# Out:
# False    6468805
# True           5
# dtype: int64

# %%
cIdx = np.logical_and(cIdx,np.logical_not(cIdx4))
cIdx.value_counts()
# Out:
# True     6462769
# False       6041
# dtype: int64

# %%
timedif = np.diff(gps['TIME'])

# %%
lons1 = gps.X[:len(gps) - 1]
lons2 = gps.X[1:len(gps)]
lats1 = gps.Y[0:len(gps) -1]
lats2 = gps.Y[1:len(gps)]

# %%
lon1 = lons1.values
lon2 = lons2.values
lat1 = lats1.values
lat2 = lats2.values

# %%
az12,az21,dist = g.inv(lon1,lat1,lon2,lat2)

# %%
len(dist)
# Out:
# 6468809

# %%
fig,ax = plt.subplots()
ax.scatter(timedif.astype(int)/10**9,dist)
fig.show()

# %%
>>> boston_lat = 42.+(15./60.); boston_lon = -71.-(7./60.)
>>> portland_lat = 45.+(31./60.); portland_lon = -123.-(41./60.)
>>> newyork_lat = 40.+(47./60.); newyork_lon = -73.-(58./60.)
>>> london_lat = 51.+(32./60.); london_lon = -(5./60.)
>>> # compute forward and back azimuths, plus distance
>>> # between Boston and Portland.
>>> az12,az21,dist = g.inv(boston_lon,boston_lat,portland_lon,portland_lat)

# %%
dist
# Out:
# 4164074.2392955828

# %%
cleanIdx = cIdx

# %%
cgps = gps[cleanIdx]

# %%
len(cgps)
# Out:
# 6462769

# %%
timeDiff = np.diff(cgps['TIME'])
timeIdx = timeDiff.astype(int)/10**9 > 100

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-c1f55c462b40> in <module>()
# ----> 1 timeIdx.value_counts()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'value_counts'

# %%
cgps['TRAJ_ID'] = np.nan
idx = np.logical_or(np.diff(cgps['MOVER_ID'])!=0, np.diff(cgps['HL'])!=0)
idx = np.logical_or(idx,timeIdx)
len(idx)
# Out:
# 6462768

# %%
idx = np.insert(idx,0,True)
t_list = ((cgps.ix[idx,'TIME'].astype(int)/10**9)/86400).astype(int)
t_list = (t_list.index * 10**5 + t_list.values)
cgps.TRAJ_ID = np.nan

# %%
cgps.head()
# Out:
#    TRAJ_ID       MOVER_ID                TIME           X          Y   V  \
# 0      NaN  8613400600341 2014-10-01 00:00:27  118.133663  24.537328  70
# 1      NaN  8613400600341 2014-10-01 00:01:28  118.129573  24.538740  12
# 2      NaN  8613400600341 2014-10-01 00:01:43  118.129165  24.538697   1
# 3      NaN  8613400600341 2014-10-01 00:02:44  118.129200  24.538700   0
# 4      NaN  8613400600341 2014-10-01 00:03:45  118.129182  24.538678   0
#
#    Degree  HL
# 0      23   0
# 1      32   0
# 2      23   0
# 3      18   0
# 4      34   0

# %%
cgps.ix[idx, 'TRAJ_ID'] = t_list

# %%
cgps.head()
# Out:
#    TRAJ_ID       MOVER_ID                TIME           X          Y   V  \
# 0    16344  8613400600341 2014-10-01 00:00:27  118.133663  24.537328  70
# 1      NaN  8613400600341 2014-10-01 00:01:28  118.129573  24.538740  12
# 2      NaN  8613400600341 2014-10-01 00:01:43  118.129165  24.538697   1
# 3      NaN  8613400600341 2014-10-01 00:02:44  118.129200  24.538700   0
# 4      NaN  8613400600341 2014-10-01 00:03:45  118.129182  24.538678   0
#
#    Degree  HL
# 0      23   0
# 1      32   0
# 2      23   0
# 3      18   0
# 4      34   0

# %%
cgps['TRAJ_ID'].fillna(method='ffill',inplace=True)

# %%
cgps.TRAJ_ID = cgps.TRAJ_ID.astype(int)
cgps.ix[cgps['HL'] > 0, 'HL'] = 1
cgps.to_csv("20141001_clean_v2.csv",index=False)

# %%
cgps.head(n=20)
# Out:
#     TRAJ_ID       MOVER_ID                TIME           X          Y   V  \
# 0     16344  8613400600341 2014-10-01 00:00:27  118.133663  24.537328  70
# 1     16344  8613400600341 2014-10-01 00:01:28  118.129573  24.538740  12
# 2     16344  8613400600341 2014-10-01 00:01:43  118.129165  24.538697   1
# 3     16344  8613400600341 2014-10-01 00:02:44  118.129200  24.538700   0
# 4     16344  8613400600341 2014-10-01 00:03:45  118.129182  24.538678   0
# 5     16344  8613400600341 2014-10-01 00:04:46  118.129145  24.538673   0
# 6     16344  8613400600341 2014-10-01 00:05:47  118.129170  24.538685   0
# 7     16344  8613400600341 2014-10-01 00:05:54  118.129158  24.538678   0
# 8     16344  8613400600341 2014-10-01 00:06:55  118.128128  24.537637   0
# 9     16344  8613400600341 2014-10-01 00:07:55  118.128098  24.537612   0
# 10    16344  8613400600341 2014-10-01 00:08:56  118.127760  24.537478   1
# 11    16344  8613400600341 2014-10-01 00:09:57  118.127738  24.536925   9
# 12  1216344  8613400600341 2014-10-01 00:11:57  118.125905  24.536025  22
# 13  1216344  8613400600341 2014-10-01 00:12:58  118.127983  24.533382   0
# 14  1216344  8613400600341 2014-10-01 00:13:59  118.127747  24.531090  51
# 15  1216344  8613400600341 2014-10-01 00:14:59  118.127297  24.524188  70
# 16  1216344  8613400600341 2014-10-01 00:16:00  118.132240  24.514153  77
# 17  1216344  8613400600341 2014-10-01 00:17:01  118.133122  24.501620  81
